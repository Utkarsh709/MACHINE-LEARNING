# %%
import numpy as np

# %%
arr1=np.array([1,2,3,4,5,6])
arr2=np.array([4,5,6,7,8,9])

# %%
arr1-arr2
# Out:
# array([-3, -3, -3, -3, -3, -3])

# %%
arr1+arr2
# Out:
# array([ 5,  7,  9, 11, 13, 15])

# %%
print(arr1*2)
# Out:
# [ 2  4  6  8 10 12]

# %%
arr1>2
# Out:
# array([False, False,  True,  True,  True,  True])

# %%
arr1*arr2
# Out:
# array([ 4, 10, 18, 28, 40, 54])

# %%
arr3=np.array([1,2,3,4,5,6]).reshape(2,3)
arr4=np.array([4,5,6,7,8,9]).reshape(3,2)

# %%
arr3
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
arr4
# Out:
# array([[4, 5],
#        [6, 7],
#        [8, 9]])

# %%
arr3.dot(arr4)
# Out:
# array([[ 40,  46],
#        [ 94, 109]])

# %%
arr3.max()
# Out:
# 6

# %%
arr3.min()
# Out:
# 1

# %%
arr3.max(axis=0)
# Out:
# array([4, 5, 6])

# %%
arr3.min(axis=1)
# Out:
# array([1, 4])

# %%
arr3.sum()
# Out:
# 21

# %%
arr3.sum(axis=0)
# Out:
# array([5, 7, 9])

# %%
arr3.mean()
# Out:
# 3.5

# %%
arr3.mean(axis=0)
# Out:
# array([2.5, 3.5, 4.5])

# %%
arr3.std()
# Out:
# 1.707825127659933

# %%
np.sin(arr3)
# Out:
# array([[ 0.84147098,  0.90929743,  0.14112001],
#        [-0.7568025 , -0.95892427, -0.2794155 ]])

# %%
np.median(arr3)
# Out:
# 3.5

# %%
np.exp(arr3)
# Out:
# array([[  2.71828183,   7.3890561 ,  20.08553692],
#        [ 54.59815003, 148.4131591 , 403.42879349]])
