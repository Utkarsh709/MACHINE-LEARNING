# %%
from sklearn.datasets import fetch_openml

# Load the Boston Housing dataset
boston = fetch_openml(name="boston", version=1, as_frame=True)

# Extract features (X) and target (y)
X, y = boston.data, boston.target

# Display first few rows
print(X.head())
print(y.head())
# Out:
#       CRIM    ZN  INDUS CHAS    NOX     RM   AGE     DIS RAD    TAX  PTRATIO  \
# 0  0.00632  18.0   2.31    0  0.538  6.575  65.2  4.0900   1  296.0     15.3
# 1  0.02731   0.0   7.07    0  0.469  6.421  78.9  4.9671   2  242.0     17.8
# 2  0.02729   0.0   7.07    0  0.469  7.185  61.1  4.9671   2  242.0     17.8
# 3  0.03237   0.0   2.18    0  0.458  6.998  45.8  6.0622   3  222.0     18.7
# 4  0.06905   0.0   2.18    0  0.458  7.147  54.2  6.0622   3  222.0     18.7
#
#         B  LSTAT
# 0  396.90   4.98
# 1  396.90   9.14
# 2  392.83   4.03
# 3  394.63   2.94
# 4  396.90   5.33
# 0    24.0
# 1    21.6
# 2    34.7
# 3    33.4
# 4    36.2
# Name: MEDV, dtype: float64

# %%
X.shape
# Out:
# (506, 13)

# %%
y.shape
# Out:
# (506,)

# %%
import numpy as np
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVR
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

svr=SVR()

# %%
estimators=[('lr',lr),('svr',svr)]

# %%
for estimator in estimators:
    scores=cross_val_score(estimator[1],X,y,cv=10,scoring='r2')
    print(estimator[0],np.round(np.mean(scores),2))
# Out:
# C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\model_selection\_validation.py:978: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_scorer.py", line 140, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_scorer.py", line 380, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_scorer.py", line 90, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\_response.py", line 242, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\linear_model\_base.py", line 297, in predict
#     return self._decision_function(X)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\linear_model\_base.py", line 279, in _decision_function
#     return X @ coef_ + self.intercept_
#            ~~^~~~~~~
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn(
# C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\model_selection\_validation.py:978: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_scorer.py", line 140, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_scorer.py", line 380, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_scorer.py", line 90, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\_response.py", line 242, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\linear_model\_base.py", line 297, in predict
#     return self._decision_function(X)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\linear_model\_base.py", line 279, in _decision_function
#     return X @ coef_ + self.intercept_
#            ~~^~~~~~~
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn(
# C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\model_selection\_validation.py:978: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_scorer.py", line 140, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_scorer.py", line 380, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_scorer.py", line 90, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\_response.py", line 242, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\linear_model\_base.py", line 297, in predict
#     return self._decision_function(X)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\linear_model\_base.py", line 279, in _decision_function
#     return X @ coef_ + self.intercept_
#            ~~^~~~~~~
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn(
# C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\model_selection\_validation.py:978: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_scorer.py", line 140, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_scorer.py", line 380, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_scorer.py", line 90, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\_response.py", line 242, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\linear_model\_base.py", line 297, in predict
#     return self._decision_function(X)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\linear_model\_base.py", line 279, in _decision_function
#     return X @ coef_ + self.intercept_
#            ~~^~~~~~~
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn(
# C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\model_selection\_validation.py:978: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_scorer.py", line 140, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_scorer.py", line 380, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_scorer.py", line 90, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\_response.py", line 242, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\linear_model\_base.py", line 297, in predict
#     return self._decision_function(X)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\linear_model\_base.py", line 279, in _decision_function
#     return X @ coef_ + self.intercept_
#            ~~^~~~~~~
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn(
# C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\model_selection\_validation.py:978: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_scorer.py", line 140, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_scorer.py", line 380, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_scorer.py", line 90, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\_response.py", line 242, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\linear_model\_base.py", line 297, in predict
#     return self._decision_function(X)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\linear_model\_base.py", line 279, in _decision_function
#     return X @ coef_ + self.intercept_
#            ~~^~~~~~~
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn(
# C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\model_selection\_validation.py:978: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_scorer.py", line 140, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_scorer.py", line 380, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_scorer.py", line 90, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\_response.py", line 242, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\linear_model\_base.py", line 297, in predict
#     return self._decision_function(X)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\linear_model\_base.py", line 279, in _decision_function
#     return X @ coef_ + self.intercept_
#            ~~^~~~~~~
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn(
# C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\model_selection\_validation.py:978: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_scorer.py", line 140, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_scorer.py", line 380, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_scorer.py", line 90, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\_response.py", line 242, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\linear_model\_base.py", line 297, in predict
#     return self._decision_function(X)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\linear_model\_base.py", line 279, in _decision_function
#     return X @ coef_ + self.intercept_
#            ~~^~~~~~~
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn(
# C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\model_selection\_validation.py:978: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_scorer.py", line 140, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_scorer.py", line 380, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_scorer.py", line 90, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\_response.py", line 242, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\linear_model\_base.py", line 297, in predict
#     return self._decision_function(X)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\linear_model\_base.py", line 279, in _decision_function
#     return X @ coef_ + self.intercept_
#            ~~^~~~~~~
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn(
# C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\model_selection\_validation.py:978: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_scorer.py", line 140, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_scorer.py", line 380, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_scorer.py", line 90, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\_response.py", line 242, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\linear_model\_base.py", line 297, in predict
#     return self._decision_function(X)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\linear_model\_base.py", line 279, in _decision_function
#     return X @ coef_ + self.intercept_
#            ~~^~~~~~~
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn(
# lr nan
# svr -0.41

# %%
from sklearn.ensemble import VotingRegressor

# %%
vr=VotingRegressor(estimators)
scores=cross_val_score(vr,X,y,scoring='accuracy',cv=10)
print(np.round(np.mean(scores),2))
# Out:
# C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\model_selection\_validation.py:978: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_scorer.py", line 140, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_scorer.py", line 380, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_scorer.py", line 90, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\_response.py", line 242, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\ensemble\_voting.py", line 720, in predict
#     return np.average(self._predict(X), axis=1, weights=self._weights_not_none)
#                       ^^^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\ensemble\_voting.py", line 76, in _predict
#     return np.asarray([est.predict(X) for est in self.estimators_]).T
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\ensemble\_voting.py", line 76, in <listcomp>
#     return np.asarray([est.predict(X) for est in self.estimators_]).T
#                        ^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\linear_model\_base.py", line 297, in predict
#     return self._decision_function(X)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\linear_model\_base.py", line 279, in _decision_function
#     return X @ coef_ + self.intercept_
#            ~~^~~~~~~
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn(
# C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\model_selection\_validation.py:978: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_scorer.py", line 140, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_scorer.py", line 380, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_scorer.py", line 90, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\_response.py", line 242, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\ensemble\_voting.py", line 720, in predict
#     return np.average(self._predict(X), axis=1, weights=self._weights_not_none)
#                       ^^^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\ensemble\_voting.py", line 76, in _predict
#     return np.asarray([est.predict(X) for est in self.estimators_]).T
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\ensemble\_voting.py", line 76, in <listcomp>
#     return np.asarray([est.predict(X) for est in self.estimators_]).T
#                        ^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\linear_model\_base.py", line 297, in predict
#     return self._decision_function(X)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\linear_model\_base.py", line 279, in _decision_function
#     return X @ coef_ + self.intercept_
#            ~~^~~~~~~
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn(
# C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\model_selection\_validation.py:978: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_scorer.py", line 140, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_scorer.py", line 380, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_scorer.py", line 90, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\_response.py", line 242, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\ensemble\_voting.py", line 720, in predict
#     return np.average(self._predict(X), axis=1, weights=self._weights_not_none)
#                       ^^^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\ensemble\_voting.py", line 76, in _predict
#     return np.asarray([est.predict(X) for est in self.estimators_]).T
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\ensemble\_voting.py", line 76, in <listcomp>
#     return np.asarray([est.predict(X) for est in self.estimators_]).T
#                        ^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\linear_model\_base.py", line 297, in predict
#     return self._decision_function(X)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\linear_model\_base.py", line 279, in _decision_function
#     return X @ coef_ + self.intercept_
#            ~~^~~~~~~
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn(
# C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\model_selection\_validation.py:978: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_scorer.py", line 140, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_scorer.py", line 380, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_scorer.py", line 90, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\_response.py", line 242, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\ensemble\_voting.py", line 720, in predict
#     return np.average(self._predict(X), axis=1, weights=self._weights_not_none)
#                       ^^^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\ensemble\_voting.py", line 76, in _predict
#     return np.asarray([est.predict(X) for est in self.estimators_]).T
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\ensemble\_voting.py", line 76, in <listcomp>
#     return np.asarray([est.predict(X) for est in self.estimators_]).T
#                        ^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\linear_model\_base.py", line 297, in predict
#     return self._decision_function(X)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\linear_model\_base.py", line 279, in _decision_function
#     return X @ coef_ + self.intercept_
#            ~~^~~~~~~
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn(
# C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\model_selection\_validation.py:978: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_scorer.py", line 140, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_scorer.py", line 380, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_scorer.py", line 90, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\_response.py", line 242, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\ensemble\_voting.py", line 720, in predict
#     return np.average(self._predict(X), axis=1, weights=self._weights_not_none)
#                       ^^^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\ensemble\_voting.py", line 76, in _predict
#     return np.asarray([est.predict(X) for est in self.estimators_]).T
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\ensemble\_voting.py", line 76, in <listcomp>
#     return np.asarray([est.predict(X) for est in self.estimators_]).T
#                        ^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\linear_model\_base.py", line 297, in predict
#     return self._decision_function(X)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\linear_model\_base.py", line 279, in _decision_function
#     return X @ coef_ + self.intercept_
#            ~~^~~~~~~
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn(
# C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\model_selection\_validation.py:978: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_scorer.py", line 140, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_scorer.py", line 380, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_scorer.py", line 90, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\_response.py", line 242, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\ensemble\_voting.py", line 720, in predict
#     return np.average(self._predict(X), axis=1, weights=self._weights_not_none)
#                       ^^^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\ensemble\_voting.py", line 76, in _predict
#     return np.asarray([est.predict(X) for est in self.estimators_]).T
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\ensemble\_voting.py", line 76, in <listcomp>
#     return np.asarray([est.predict(X) for est in self.estimators_]).T
#                        ^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\linear_model\_base.py", line 297, in predict
#     return self._decision_function(X)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\linear_model\_base.py", line 279, in _decision_function
#     return X @ coef_ + self.intercept_
#            ~~^~~~~~~
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn(
# C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\model_selection\_validation.py:978: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_scorer.py", line 140, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_scorer.py", line 380, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_scorer.py", line 90, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\_response.py", line 242, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\ensemble\_voting.py", line 720, in predict
#     return np.average(self._predict(X), axis=1, weights=self._weights_not_none)
#                       ^^^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\ensemble\_voting.py", line 76, in _predict
#     return np.asarray([est.predict(X) for est in self.estimators_]).T
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\ensemble\_voting.py", line 76, in <listcomp>
#     return np.asarray([est.predict(X) for est in self.estimators_]).T
#                        ^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\linear_model\_base.py", line 297, in predict
#     return self._decision_function(X)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\linear_model\_base.py", line 279, in _decision_function
#     return X @ coef_ + self.intercept_
#            ~~^~~~~~~
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn(
# C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\model_selection\_validation.py:978: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_scorer.py", line 140, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_scorer.py", line 380, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_scorer.py", line 90, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\_response.py", line 242, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\ensemble\_voting.py", line 720, in predict
#     return np.average(self._predict(X), axis=1, weights=self._weights_not_none)
#                       ^^^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\ensemble\_voting.py", line 76, in _predict
#     return np.asarray([est.predict(X) for est in self.estimators_]).T
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\ensemble\_voting.py", line 76, in <listcomp>
#     return np.asarray([est.predict(X) for est in self.estimators_]).T
#                        ^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\linear_model\_base.py", line 297, in predict
#     return self._decision_function(X)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\linear_model\_base.py", line 279, in _decision_function
#     return X @ coef_ + self.intercept_
#            ~~^~~~~~~
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn(
# C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\model_selection\_validation.py:978: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_scorer.py", line 140, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_scorer.py", line 380, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_scorer.py", line 90, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\_response.py", line 242, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\ensemble\_voting.py", line 720, in predict
#     return np.average(self._predict(X), axis=1, weights=self._weights_not_none)
#                       ^^^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\ensemble\_voting.py", line 76, in _predict
#     return np.asarray([est.predict(X) for est in self.estimators_]).T
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\ensemble\_voting.py", line 76, in <listcomp>
#     return np.asarray([est.predict(X) for est in self.estimators_]).T
#                        ^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\linear_model\_base.py", line 297, in predict
#     return self._decision_function(X)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\linear_model\_base.py", line 279, in _decision_function
#     return X @ coef_ + self.intercept_
#            ~~^~~~~~~
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn(
# nan
# C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\model_selection\_validation.py:978: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_scorer.py", line 140, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_scorer.py", line 380, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_scorer.py", line 90, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\_response.py", line 242, in _get_response_values
#     y_pred, pos_label = prediction_method(X), None
#                         ^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\ensemble\_voting.py", line 720, in predict
#     return np.average(self._predict(X), axis=1, weights=self._weights_not_none)
#                       ^^^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\ensemble\_voting.py", line 76, in _predict
#     return np.asarray([est.predict(X) for est in self.estimators_]).T
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\ensemble\_voting.py", line 76, in <listcomp>
#     return np.asarray([est.predict(X) for est in self.estimators_]).T
#                        ^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\linear_model\_base.py", line 297, in predict
#     return self._decision_function(X)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\AS\AppData\Roaming\Python\Python311\site-packages\sklearn\linear_model\_base.py", line 279, in _decision_function
#     return X @ coef_ + self.intercept_
#            ~~^~~~~~~
# TypeError: can't multiply sequence by non-int of type 'float'
#
#   warnings.warn(
