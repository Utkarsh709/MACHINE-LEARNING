# %%
import numpy as np
import pandas as pd

# %%
match=pd.read_csv('matches.csv')

# %%
match.head(3)
# Out:
#    id  season       city        date                team1  \
# 0   1    2017  Hyderabad  2017-04-05  Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06       Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07        Gujarat Lions
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
#
#    result  dl_applied                  winner  win_by_runs  win_by_wickets  \
# 0  normal           0     Sunrisers Hyderabad           35               0
# 1  normal           0  Rising Pune Supergiant            0               7
# 2  normal           0   Kolkata Knight Riders            0              10
#
#   player_of_match                                      venue         umpire1  \
# ...

# %%
match.pivot_table(index='winner',columns='city',values='win_by_runs')
# Out:
# city                         Abu Dhabi  Ahmedabad  Bangalore  Bloemfontein  \
# winner
# Chennai Super Kings               93.0        NaN  19.500000           NaN
# Deccan Chargers                    NaN        NaN   0.000000           NaN
# Delhi Daredevils                   NaN   0.000000   5.666667          14.0
# Gujarat Lions                      NaN        NaN   0.000000           NaN
# Kings XI Punjab                   11.5   0.000000  10.200000           0.0
# Kochi Tuskers Kerala               NaN        NaN        NaN           NaN
# Kolkata Knight Riders             41.0        NaN  30.333333           NaN
# Mumbai Indians                     NaN  25.000000   9.375000           NaN
# Pune Warriors                      NaN        NaN        NaN           NaN
# Rajasthan Royals                   0.0  17.571429  19.666667           NaN
# Rising Pune Supergiant             NaN        NaN  27.000000           NaN
# ...
